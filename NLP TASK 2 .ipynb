# %%
#BARANI DHARAN S
#20BCE0044
#NLP TASK 2
from time import ctime
print(ctime())
import nltk
# Out:
# Thu Dec 22 14:59:21 2022

# %%
#FREQUENCY DISTRIBUTION 
text1='VIT was established with the aim of providing quality higher education on par with international standards. It persistently seeks and adopts innovative methods to improve the quality of higher education on a consistent basis.'
fd=nltk.FreqDist(text1.split())
fd
# Out:
# FreqDist({'with': 2, 'the': 2, 'of': 2, 'quality': 2, 'higher': 2, 'education': 2, 'on': 2, 'VIT': 1, 'was': 1, 'established': 1, ...})

# %%
#CONDITIONAL FREQUENCY DISTRIBUTION 
from nltk.probability import ConditionalFreqDist
cfd=ConditionalFreqDist((len(word),word) for word in text1.split())
cfd[4]
# Out:
# FreqDist({'with': 2})

# %%
# to with inaugural 
from nltk.corpus import inaugural

# %%
from nltk.probability import ConditionalFreqDist
text2=inaugural.words(fileids='2005-Bush.txt')
cfd=ConditionalFreqDist((len(word),word) for word in text2)
cfd[4]
# Out:
# FreqDist({'that': 27, 'have': 24, 'will': 22, 'this': 14, 'your': 12, 'time': 7, 'free': 7, 'seen': 6, 'hope': 6, 'with': 6, ...})

# %%
#CHINESE SEGMENTATION USING JIEBA 
#after installing jeiba module using pip install jieba in terminal
import jieba

# %%
seg=jieba.cut('感谢您关于自然语言的精彩讲座',cut_all=True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\baran\AppData\Local\Temp\jieba.cache
# Loading model cost 2.397 seconds.
# Prefix dict has been built successfully.
# 感谢 感谢您 关于 自然 自然语言 语言 的 精彩 讲座

# %%
#BASIC TEXT PROCESSING PIPELINE 
import nltk 
sent="Become an expert in NLP"
words=nltk.word_tokenize(sent)
print(words)
# Out:
# ['Become', 'an', 'expert', 'in', 'NLP']

# %%
import nltk
texts="Dhoni made his ODI debut on 23 December 2004, against Bangladesh in Chittagong, and played his first Test a year later against Sri Lanka. He played his first T20I also a year later against South Africa. In 2007, he took over the ODI captaincy from Rahul Dravid and he also selected as T20I captain of India in this year. In 2008, he was selected as Test captain. His captaincy record in Tests format was mixed, successfully leading India to a series win against New Zealand in 2008 and the Border-Gavaskar Trophy (home series in 2010 and 2013) against Australia while losing to Sri Lanka, Australia, England, and South Africa by big margins in away conditions."
for text in texts:
    sentences=nltk.sent_tokenize(text)
    for sentence in sentences:
        words=nltk.word_tokenize(sentence)
        print(words)
        tagged=nltk.pos_tag(words)
        print(tagged)
# Out:
# ['D']
# [('D', 'NN')]
# ['h']
# [('h', 'NN')]
# ['o']
# [('o', 'NN')]
# ['n']
# [('n', 'NN')]
# ['i']
# [('i', 'NN')]
# ['m']
# [('m', 'NN')]
# ['a']
# [('a', 'DT')]
# ['d']
# [('d', 'NN')]
# ['e']
# [('e', 'NN')]
# ['h']
# [('h', 'NN')]
# ['i']
# [('i', 'NN')]
# ['s']
# [('s', 'NN')]
# ['O']
# [('O', 'NN')]
# ['D']
# [('D', 'NN')]
# ['I']
# [('I', 'PRP')]
# ['d']
# [('d', 'NN')]
# ['e']
# [('e', 'NN')]
# ['b']
# [('b', 'NN')]
# ['u']
# [('u', 'NN')]
# ['t']
# [('t', 'NN')]
# ['o']
# [('o', 'NN')]
# ['n']
# [('n', 'NN')]
# ['2']
# [('2', 'CD')]
# ['3']
# [('3', 'CD')]
# ['D']
# [('D', 'NN')]
# ['e']
# [('e', 'NN')]
# ['c']
# [('c', 'NNS')]
# ['e']
# [('e', 'NN')]
# ['m']
# [('m', 'NN')]
# ['b']
# [('b', 'NN')]
# ['e']
# [('e', 'NN')]
# ['r']
# [('r', 'NN')]
# ['2']
# [('2', 'CD')]
# ['0']
# [('0', 'CD')]
# ['0']
# [('0', 'CD')]
# ['4']
# [('4', 'CD')]
# [',']
# [(',', ',')]
# ['a']
# [('a', 'DT')]
# ['g']
# [('g', 'NN')]
# ['a']
# [('a', 'DT')]
# ['i']
# [('i', 'NN')]
# ['n']
# ...
